# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = {
'Молоко': np.random.normal(50, 5, 12),
'Яйца': np.random.normal(67, 6, 12),
'Хлеб': np.random.normal(100, 7, 12),
'Мясо': np.random.normal(48, 4, 12),
'Соль': np.random.normal(89, 40, 12),
'Cахар': np.random.normal(100, 49, 12),
'Пшено': np.random.normal(48, 7, 12),
'Гречка': np.random.normal(75, 10, 12),
'Мыло': np.random.normal(15, 4, 12),
"Сигареты": np.random.normal(70, 15, 12),
}
df = pd.DataFrame(data).transpose()
df
# Out:
#                   0           1           2           3           4   \
# Молоко     36.792867   55.148811   47.044329   57.604452   45.352348
# Яйца       73.349458   65.422666   76.209859   69.379428   71.015564
# Хлеб       99.659228   94.772177   90.149927   94.467335   88.848680
# Мясо       43.775917   55.458037   54.070616   49.066164   52.896498
# Соль       75.380611  114.501712  116.070852   41.991879  110.388937
# Cахар     142.604563   76.310240   46.644460  116.676195   81.986780
# Пшено      37.935816   52.781549   51.387225   37.369821   48.195113
# Гречка     71.260634   67.184474   71.312482   97.556678   74.935493
# Мыло       19.039089   11.899211   18.466340   14.995705   12.956809
# Сигареты   63.061463   71.136601   72.562787   80.922125   79.867299
#
#                   5           6           7           8           9   \
# Молоко     52.208544   48.714673   48.660516   43.938279   46.971647
# Яйца       65.856917   66.419316   67.199261   69.335076   67.056382
# Хлеб      104.169074   91.392278   99.292772  100.256632  101.909684
# Мясо       50.520091   44.445407   50.026999   41.037868   46.098001
# Соль      116.002451  100.675930   92.781995   72.779755  139.012167
# Cахар     122.781043  103.543828  175.681038  144.003482  137.645618
# Пшено      38.193100   45.207009   53.003757   50.287859   57.448959
# Гречка     73.426852   91.844228   86.470389   74.848667   95.928499
# Мыло       22.388156   12.326771   16.551019   19.399800   18.873758
# Сигареты   60.967949   66.160803   76.120091   68.591431   65.612166
#
#                   10          11
# Молоко     53.941125   47.772684
# Яйца       51.645373   68.914229
# Хлеб      100.258048  105.112727
# Мясо       51.350510   48.645753
# Соль       79.628601  116.828377
# Cахар     182.354774  124.897146
# Пшено      42.691780   42.142429
# Гречка     54.680700   51.820629
# Мыло       16.878245   13.900543
# Сигареты   68.553757   77.132386

# %%
ax = sns.lineplot(df)
sns.move_legend(ax, 'upper left', bbox_to_anchor=(1, 1))

# %%
p0 = df.sum() / df.shape[0]
p0
# Out:
# 0     66.285964
# 1     66.461548
# 2     64.391888
# 3     66.002978
# 4     66.644352
# 5     70.651418
# 6     67.073024
# 7     76.578784
# 8     68.447885
# 9     77.655688
# 10    70.198291
# 11    69.716690
# dtype: float64

# %%
std = ((df - p0) ** 2).sum() / (df.shape[0] - 1)
std = std ** (1/2)
print(std)
# Out:
# 0     35.774908
# 1     27.168303
# 2     27.058023
# 3     31.557946
# 4     27.426240
# 5     33.583068
# 6     29.795387
# 7     42.725607
# 8     34.750729
# 9     39.922116
# 10    45.189081
# 11    36.047013
# dtype: float64

# %%
x_extrapol = p0 + np.random.normal(0, std, len(p0))
pd.concat([df, pd.DataFrame([x_extrapol], columns = x_extrapol.index)]).reset_index(drop = True)
# Out:
#             0           1           2           3           4           5   \
# 0    36.792867   55.148811   47.044329   57.604452   45.352348   52.208544
# 1    73.349458   65.422666   76.209859   69.379428   71.015564   65.856917
# 2    99.659228   94.772177   90.149927   94.467335   88.848680  104.169074
# 3    43.775917   55.458037   54.070616   49.066164   52.896498   50.520091
# 4    75.380611  114.501712  116.070852   41.991879  110.388937  116.002451
# 5   142.604563   76.310240   46.644460  116.676195   81.986780  122.781043
# 6    37.935816   52.781549   51.387225   37.369821   48.195113   38.193100
# 7    71.260634   67.184474   71.312482   97.556678   74.935493   73.426852
# 8    19.039089   11.899211   18.466340   14.995705   12.956809   22.388156
# 9    63.061463   71.136601   72.562787   80.922125   79.867299   60.967949
# 10   76.245660   39.174662   46.338689   24.239995   74.162497  104.821256
#
#             6           7           8           9           10          11
# 0    48.714673   48.660516   43.938279   46.971647   53.941125   47.772684
# 1    66.419316   67.199261   69.335076   67.056382   51.645373   68.914229
# 2    91.392278   99.292772  100.256632  101.909684  100.258048  105.112727
# 3    44.445407   50.026999   41.037868   46.098001   51.350510   48.645753
# 4   100.675930   92.781995   72.779755  139.012167   79.628601  116.828377
# 5   103.543828  175.681038  144.003482  137.645618  182.354774  124.897146
# 6    45.207009   53.003757   50.287859   57.448959   42.691780   42.142429
# 7    91.844228   86.470389   74.848667   95.928499   54.680700   51.820629
# 8    12.326771   16.551019   19.399800   18.873758   16.878245   13.900543
# 9    66.160803   76.120091   68.591431   65.612166   68.553757   77.132386
# 10   44.550235   18.391939  100.299521   79.812157   81.770349  116.602595

# %%
reliability = std/p0
print(reliability)
# Out:
# 0     0.539706
# 1     0.408782
# 2     0.420209
# 3     0.478129
# 4     0.411531
# 5     0.475335
# 6     0.444223
# 7     0.557930
# 8     0.507696
# 9     0.514091
# 10    0.643735
# 11    0.517050
# dtype: float64

# %%
cond1 = ((df - p0) < 2 * std).all()
cond1
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11     True
# dtype: bool

# %%
cond2 = p0 > 2 * std
cond2
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# dtype: bool

# %%
cond3 = (df > 0).all()
cond3
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# dtype: bool

# %%
product_color = pd.Series(dtype = 'string')
for name in df.columns:
    if (not cond3[name]):
        product_color[name] = 'Красный'
    elif (not cond1[name] and not cond2[name]):
        product_color[name] = 'Оранжевый'
    elif (not cond1[name] or not cond2[name]):
        product_color[name] = 'Жёлтый'
    else:
        product_color[name] = 'Зелёный'
product_color
# Out:
# 0     Оранжевый
# 1       Зелёный
# 2       Зелёный
# 3       Зелёный
# 4       Зелёный
# 5       Зелёный
# 6       Зелёный
# 7     Оранжевый
# 8     Оранжевый
# 9        Жёлтый
# 10    Оранжевый
# 11       Жёлтый
# dtype: object
